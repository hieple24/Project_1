# %%
import requests
import os
import json
from dotenv import load_dotenv
import pandas as pd
from pathlib import Path
import plotly.graph_objects as go
from twarc import Twarc2

# %%
load_dotenv()
# Out:
# True

# %%
# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'

bearer_token = "bearer_token" 

bearer_token = os.environ.get("bearer_token")

search_url = "https://api.twitter.com/2/tweets/counts/recent?granularity=hour&query=Binance%20Coin%20OR%20BNB"

# Optional params: start_time,end_time,since_id,until_id,next_token,granularity

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentTweetCountsPython"
    return r

# %%
def connect_to_endpoint(url):
    response = requests.request("GET", search_url, auth=bearer_oauth)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def main():
    json_response = connect_to_endpoint(search_url)
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
if __name__ == "__main__":
    
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "end": "2021-10-02T23:00:00.000Z",
#             "start": "2021-10-02T22:51:04.000Z",
#             "tweet_count": 829
#         },
#         {
#             "end": "2021-10-03T00:00:00.000Z",
#             "start": "2021-10-02T23:00:00.000Z",
#             "tweet_count": 5932
#         },
#         {
#             "end": "2021-10-03T01:00:00.000Z",
#             "start": "2021-10-03T00:00:00.000Z",
#             "tweet_count": 6084
#         },
#         {
#             "end": "2021-10-03T02:00:00.000Z",
#             "start": "2021-10-03T01:00:00.000Z",
#             "tweet_count": 7327
#         },
#         {
#             "end": "2021-10-03T03:00:00.000Z",
#             "start": "2021-10-03T02:00:00.000Z",
#             "tweet_count": 8929
#         },
#         {
#             "end": "2021-10-03T04:00:00.000Z",
#             "start": "2021-10-03T03:00:00.000Z",
#             "tweet_count": 7509
#         },
#         {
# ...
